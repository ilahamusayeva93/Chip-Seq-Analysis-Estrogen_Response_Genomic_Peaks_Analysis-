# %%
# Install sra-tools to download and extract FASTQ files from SRA
# !apt-get install sra-toolkit

# Download SRA files using prefetch (part of sra-tools)
# !prefetch SRR1021789
# !prefetch SRR1021804
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 45 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# ...

# %%
# Convert downloaded SRA files to FASTQ format
# !fastq-dump --split-files /content/SRR1021789/SRR1021789.sra
# !fastq-dump --split-files /content/SRR1021804/SRR1021804.sra
# Out:
# Read 29151735 spots for /content/SRR1021789/SRR1021789.sra
# Written 29151735 spots for /content/SRR1021789/SRR1021789.sra
# Read 22196096 spots for /content/SRR1021804/SRR1021804.sra
# Written 22196096 spots for /content/SRR1021804/SRR1021804.sra

# %%
# !apt-get install fastqc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra libapache-pom-java
#   libargs4j-java libatk-wrapper-java libatk-wrapper-java-jni libcommons-compress-java
#   libcommons-io-java libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl libfontenc1 libhtsjdk-java
#   libjbzip2-java libjson-simple-java libngs-java libngs-sdk-dev libngs-sdk2 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java libsnappy-jni libxkbfile1
#   libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   libxz-java libcommons-io-java-doc libcommons-lang3-java-doc libavalon-framework-java
#   libcommons-logging-java-doc libexcalibur-logkit-java liblog4j1.2-java picard-tools
# ...

# %%
# !fastqc /content/SRR1021789_1.fastq
# !fastqc /content/SRR1021804_1.fastq
# Out:
# Started analysis of SRR1021789_1.fastq
# Approx 5% complete for SRR1021789_1.fastq
# Approx 10% complete for SRR1021789_1.fastq
# Approx 15% complete for SRR1021789_1.fastq
# Approx 20% complete for SRR1021789_1.fastq
# Approx 25% complete for SRR1021789_1.fastq
# Approx 30% complete for SRR1021789_1.fastq
# Approx 35% complete for SRR1021789_1.fastq
# Approx 40% complete for SRR1021789_1.fastq
# Approx 45% complete for SRR1021789_1.fastq
# Approx 50% complete for SRR1021789_1.fastq
# Approx 55% complete for SRR1021789_1.fastq
# Approx 60% complete for SRR1021789_1.fastq
# Approx 65% complete for SRR1021789_1.fastq
# Approx 70% complete for SRR1021789_1.fastq
# Approx 75% complete for SRR1021789_1.fastq
# Approx 80% complete for SRR1021789_1.fastq
# Approx 85% complete for SRR1021789_1.fastq
# Approx 90% complete for SRR1021789_1.fastq
# Approx 95% complete for SRR1021789_1.fastq
# Analysis complete for SRR1021789_1.fastq
# Started analysis of SRR1021804_1.fastq
# ...

# %%
# !apt-get install bowtie2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   bowtie2-examples
# The following NEW packages will be installed:
#   bowtie2
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,169 kB of archives.
# After this operation, 3,735 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 bowtie2 amd64 2.4.4-1 [1,169 kB]
# Fetched 1,169 kB in 2s (579 kB/s)
# Selecting previously unselected package bowtie2.
# (Reading database ... 122702 files and directories currently installed.)
# Preparing to unpack .../bowtie2_2.4.4-1_amd64.deb ...
# Unpacking bowtie2 (2.4.4-1) ...
# Setting up bowtie2 (2.4.4-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/hg19.zip -d /content/drive/MyDrive/hg19_index

# %%
# !bowtie2 -p 2 -x /content/drive/MyDrive/hg19_index/hg19 -U /content/SRR1021789_1.fastq -S /content/SRR1021789_aligned.sam
# Out:
# 29151735 reads; of these:
#   29151735 (100.00%) were unpaired; of these:
#     95760 (0.33%) aligned 0 times
#     26027413 (89.28%) aligned exactly 1 time
#     3028562 (10.39%) aligned >1 times
# 99.67% overall alignment rate
# 22196096 reads; of these:
#   22196096 (100.00%) were unpaired; of these:
#     67084 (0.30%) aligned 0 times
#     19174120 (86.39%) aligned exactly 1 time
#     2954892 (13.31%) aligned >1 times
# 99.70% overall alignment rate

# %%
# !bowtie2 -p 2 -x /content/drive/MyDrive/hg19_index/hg19 -U /content/SRR1021804_1.fastq -S /content/SRR1021804_aligned.sam
# Out:
# 22196096 reads; of these:
#   22196096 (100.00%) were unpaired; of these:
#     67084 (0.30%) aligned 0 times
#     19174120 (86.39%) aligned exactly 1 time
#     2954892 (13.31%) aligned >1 times
# 99.70% overall alignment rate

# %%
# !pip install MACS2

# !macs2 callpeak -t /content/SRR1021789_aligned.sam -c /content/SRR1021804_aligned.sam -f SAM -g hs -n estrogen
# Out:
# ...
# INFO  @ Mon, 01 Apr 2024 07:51:07:
# # Command line: callpeak -t /content/SRR1021789_aligned.sam -c /content/SRR1021804_aligned.sam -f SAM -g hs -n estrogen
# # ARGUMENTS LIST:
# # name = estrogen
# # format = SAM
# # ChIP-seq file = ['/content/SRR1021789_aligned.sam']
# # control file = ['/content/SRR1021804_aligned.sam']
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 1000 bps and 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
#
# INFO  @ Mon, 01 Apr 2024 07:51:07: #1 read tag files...
# INFO  @ Mon, 01 Apr 2024 07:51:07: #1 read treatment tags...
# INFO  @ Mon, 01 Apr 2024 07:51:09:  1000000
# ...

# %%
# !pip install pybedtools
from pybedtools import BedTool

# Convert peak file to BedTool object
peaks = BedTool('/content/estrogen_peaks.narrowPeak')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 75.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 25.3 MB/s eta 0:00:00
# ...
#   Created wheel for pybedtools: filename=pybedtools-0.9.1-cp310-cp310-linux_x86_64.whl size=13997646 sha256=d8c9d5eee23d06b80c0ac8ecccc899c851928b540687f66b6fb1f76d254f1e15
#   Stored in directory: /root/.cache/pip/wheels/f5/79/76/c2cef660013cdf573214696aec4bc7ec352bf46141682230af
# Successfully built pybedtools
# ...

# %%
peaks
# Out:
# <BedTool(/content/estrogen_peaks.narrowPeak)>
